# %%
import seaborn as sns
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x = 'total_bill', y= 'tip',size= 'size', hue = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y= 'tip',hue ='time', data = tips)

# %%
corr = tips.corr()
sns.heatmap(corr,cmap='coolwarm')
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_3340912b_284c_11ec_8d12_14f6d8671e42row0_col0,#T_3340912b_284c_11ec_8d12_14f6d8671e42row1_col1,#T_3340912b_284c_11ec_8d12_14f6d8671e42row2_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3340912b_284c_11ec_8d12_14f6d8671e42row0_col1{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_3340912b_284c_11ec_8d12_14f6d8671e42row0_col2{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_3340912b_284c_11ec_8d12_14f6d8671e42row1_col0{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_3340912b_284c_11ec_8d12_14f6d8671e42row1_col2,#T_3340912b_284c_11ec_8d12_14f6d8671e42row2_col0,#T_3340912b_284c_11ec_8d12_14f6d8671e42row2_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
# ...

# %%
sns.relplot(x = 'total_bill', y= 'tip',hue ='smoker', data = tips)

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y= 'tip',hue ='smoker', style= 'time', data = tips)

# %%
sns.relplot(data = tips, x = 'total_bill', y= 'tip',hue ='size', palette='winter' )

# %%
sns.relplot(data = tips, x = 'total_bill', y= 'tip',size ='size' )

# %%
sns.relplot(data = tips, x = 'total_bill', y= 'tip',size ='size', sizes=(50,200) )

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  0.041770
# 1     1  0.149610
# 2     2 -0.818129
# 3     3 -0.695437
# 4     4 -2.491587

# %%
sns.relplot(data = df, x = 'time', y = 'value', kind = 'line')

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', kind = 'line')

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', kind = 'line', ci = False) # ci= confidence interval

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', estimator = None, kind = 'line')

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', ci =False)

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', style = 'event', hue  = 'region', kind = 'line', markers = True)

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', hue = 'event', style ='event', kind = 'line', ci = False)

# %%
dots = sns.load_dataset('dots').query("align =='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(data = dots, x = 'time', y ='firing_rate', kind = 'line', size = 'coherence', hue = 'coherence', style = 'choice' , sizes=(1,5))

# %%
df = pd.DataFrame(dict(time = pd.date_range('2020-06-02', periods = 500), value = randn(500).cumsum()))

# %%
df.tail()
# Out:
#           time      value
# 495 2021-10-10 -37.325509
# 496 2021-10-11 -37.742023
# 497 2021-10-12 -37.174919
# 498 2021-10-13 -37.459255
# 499 2021-10-14 -37.309969

# %%
g = sns.relplot(data= df, x = 'time', y = 'value', kind ='line')
g.fig.autofmt_xdate()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.relplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', col = 'sex')
sns.relplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', col = 'time')

# %%
sns.relplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', col = 'sex', row = 'time')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.rename(columns={'size': 'size_renamed'}, inplace=True)

# %%
sns.relplot(data = tips, x = 'total_bill', y='tip', hue = 'smoker', col = 'size_renamed', col_wrap=3, height=3)

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data = fmri, x = 'timepoint', y='signal', hue = 'region',style ='event', markers = True, ci = 68, err_style = 'bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = dots, x = 'time', y='firing_rate', hue='coherence', style ='choice')
# Out:
# <AxesSubplot:xlabel='time', ylabel='firing_rate'>

# %%
sns.scatterplot(data = dots, x = 'time', y='firing_rate', hue='coherence', style ='choice')
# Out:
# <AxesSubplot:xlabel='time', ylabel='firing_rate'>

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip', hue ='sex', size='size_renamed')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(data = iris, x = 'sepal_length', y= 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %% [markdown]
#  # 2. Categorical data ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size_renamed'], dtype='object')

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#catplot

# %%
sns.catplot(data = tips,x='day', y = 'total_bill' )

# %%
sns.catplot(data = tips,x='day', y = 'total_bill' , hue= 'sex', jitter= False)

# %%
sns.catplot(data = tips,x='day', y = 'total_bill' , hue= 'size_renamed', kind = 'swarm')

# %%
sns.catplot(data = tips, x= 'smoker',y='tip',order=['No','Yes'], hue = 'sex')

# %%
dmnd = sns.load_dataset('diamonds')

# %%
dmnd.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
sns.catplot(data= dmnd.sort_values('color'), x= 'color', y= 'price')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size_renamed'], dtype='object')

# %%
sns.catplot(data = tips,x= 'day', y = 'tip', kind = 'boxen')

# %%
sns.relplot(data = tips,x= 'total_bill', y = 'tip', hue= 'day')

# %%
sns.catplot(data = tips,x= 'day', y = 'tip', kind = 'violin')

# %%
sns.catplot(data = tips,x= 'total_bill', y = 'day', hue = 'sex', kind = 'violin', split =True, inner = 'stick')

# %%
g = sns.catplot(data= tips, x = 'day', y = 'total_bill',kind = 'violin')
sns.swarmplot(data = tips, x ='day',y='total_bill',color= 'k', size= 3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data = titanic, x = 'class', y ='survived', kind='bar',hue = 'sex' )

# %%
sns.catplot(data = titanic, x = 'sex', y ='survived', kind='bar', hue = 'class' )

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data = titanic, x = 'deck',kind='count', hue = 'sex', palette='ch:0.95')

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.catplot(data = titanic, x = 'deck', kind='count', hue = 'class', palette='ch:0.95')

# %%
sns.catplot(data = titanic, x = 'sex', y = 'survived', kind='point', hue = 'class', palette='ch:0.95')

# %% [markdown]
#  # 3. Visualization of Distributed data
#  - Distplot()
#  - KDEPLOT()
#  - JOINTPLOT()
#  - RUGPLOT()

# %%
x = randn(100)

# %%
sns.distplot(x, kde =False, rug = True)
# Out:
# C:\Users\Rizwan\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Rizwan\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
sns.jointplot(data = tips, x ='total_bill',y='tip', kind = 'hex')

# %%
sns.set()
sns.jointplot(data = tips, x ='total_bill',y='tip', kind = 'kde', shade = True)
#sns.set_theme()

# %%
g = sns.jointplot(data = tips, x ='total_bill',y='tip', kind = 'kde', shade = True, color = 'm')
g.plot_joint(plt.scatter,c='r' , marker='+')

# %%
sns.pairplot(data = iris, hue = 'species')

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %% [markdown]
# # 4. Linear Regression Visualization
# - regplot()
# - implot()

# %%
tips['size']=tips['size_renamed']

# %%
tips  = tips.drop('size_renamed', axis=1)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex')

# %%
sns.lmplot(data=tips, x='size', y='tip', x_jitter=0.05)

# %%
sns.lmplot(data=tips,x='size', y='tip', x_estimator=np.mean)

# %%
ans = sns.load_dataset('anscombe')

# %%
ans.query("dataset == 'I'")
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
sns.lmplot(data= ans.query("dataset == 'I'"), x='x', y='y', ci = None)

# %%
sns.lmplot(data= ans.query("dataset == 'II'"), x='x', y='y', ci = None, robust = True)

# %%
sns.lmplot(data= ans.query("dataset == 'II'"), x='x', y='y', ci = None, order = True)

# %%
sns.lmplot(data= ans.query("dataset == 'III'"), x='x', y='y', ci = None, robust = True)

# %%
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(data= tips, x = 'total_bill', y = 'tip')

# %%
sns.lmplot(data= tips, x = 'total_bill', y = 'tip',col= 'day', col_wrap=2, height=6)

# %% [markdown]
# # 5. Controlling ploted Figure Aesthetics
# - fiure style
# - axes styling
# - color palettes
# - etc..

# %%
def sinplot(flip =5):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sns.set_context('talk', font_scale=0.5)
sns.set_style( 'white', {'text.color': '.25', 'xtick.direction': 'out'})
sinplot()
sns.despine(left = True, bottom =True)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]
